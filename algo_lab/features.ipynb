# %% [markdown]
# #### Return(t-1) as a feature
# -

# %%
import jarjarquant
import pandas as pd

# %%
jarjarquant.Labelling.from_random_series(periods=2520, loc=0.005, )

# %%
features_df = pd.read_csv("data/close.csv").set_index("Unnamed: 0")

# %%
jjq_features = jarjarquant.FeatureEngineering(features_df=features_df)
jjq_features.fracDiff_FFD(d=0.5)
# Out:
#                price
# Unnamed: 0
# 2100-01-01       NaN
# 2100-01-04       NaN
# 2100-01-05       NaN
# 2100-01-06       NaN
# 2100-01-07       NaN
# ...              ...
# 2109-08-23 -0.366252
# 2109-08-26 -0.359632
# 2109-08-27 -0.360049
# 2109-08-28 -0.357460
# 2109-08-29 -0.357239
#
# [2520 rows x 1 columns]

# %%
features_df.plot()
# Out:
# <Axes: xlabel='Unnamed: 0'>

# %%
jjq_features.features_df.plot()
# Out:
# <Axes: xlabel='Unnamed: 0'>
